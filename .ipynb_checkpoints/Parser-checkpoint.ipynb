# %%
# %load parser.py
# import the panda, request, and io library
import pandas as pd
import requests
import io

# construct the query data
query = {

  "query": "annotation:(type:transmem) (organism:\"Homo sapiens (Human) [9606]\" OR organism:\"Mus musculus (Mouse) [10090]\")",
  "columns":"id,comment(SUBCELLULAR LOCATION)",
  "format": "tab"

}

# get the data from uni prot
r = requests.get("http://www.uniprot.org/uniprot/", params = query)

# Simple expression to find annotation data
def findAnnotation(text):
  text = str(text)
  # Now check for an annotation dictionary
  if text.find("{") != -1:
    return text[text.find("{") + 1: text.find("}")]
  else:
    return "None"

# expression to check for the type of protein
def findType(entry):
  entry = str(entry)
  # Check for single, multi, beta or other
  if entry.find("Single-pass") != -1:
    return "Single-pass membrane protein"
  elif entry.find("Multi-pass") != -1:
    return "Multi-pass membrane protein"
  elif entry.find("Beta-barrel") != -1:
    return "Beta-barrel membrane protein"
  else:
    return "Data unknown"

# read in the table data and set column names
data = pd.read_table(io.StringIO(r.text), header=0, names = ["UniProtId", "Subcellular"])

# Add the type column
data["Type"] = data["Subcellular"].apply(lambda x: findType(x))

# Add the annotation column
data["Annotations"] = data["Subcellular"].apply(lambda x: findAnnotation(x))

# now delete the subcellular column
del data["Subcellular"]

# now write the table to a file
data.to_csv("formatted.tab", index=False, header=True, sep="	")

data
# Out:
#         UniProtId                          Type  \
# 0          P34968   Multi-pass membrane protein
# 1          P29275   Multi-pass membrane protein
# 2          Q8K440   Multi-pass membrane protein
# 3          Q9BZC7   Multi-pass membrane protein
# 4          Q8R420   Multi-pass membrane protein
# 5          O35600   Multi-pass membrane protein
# 6          Q8K448   Multi-pass membrane protein
# 7          Q8K441   Multi-pass membrane protein
# 8          Q8WWZ4   Multi-pass membrane protein
# 9          Q86UQ4   Multi-pass membrane protein
# 10         Q9CXJ4   Multi-pass membrane protein
# 11         Q9JI39   Multi-pass membrane protein
# 12         O95342   Multi-pass membrane protein
# 13         Q96J66   Multi-pass membrane protein
# 14         P33897   Multi-pass membrane protein
# 15         Q91X60   Multi-pass membrane protein
# 16         Q8R4G9   Multi-pass membrane protein
# 17         P36544   Multi-pass membrane protein
# 18         P17787   Multi-pass membrane protein
# 19         P11229   Multi-pass membrane protein
# 20         Q9ERZ4   Multi-pass membrane protein
# 21         Q9ERZ3   Multi-pass membrane protein
# 22         P08173   Multi-pass membrane protein
# 23         Q9CZW4  Single-pass membrane protein
# 24         Q8JZR0  Single-pass membrane protein
# 25         Q9UKU0  Single-pass membrane protein
# 26         Q8K348  Single-pass membrane protein
# 27         Q61288  Single-pass membrane protein
# 28         P18825   Multi-pass membrane protein
# 29         Q8K410  Single-pass membrane protein
# ...           ...                           ...
# 48754  A0A0U5J6H2                  Data unknown
# 48755  A0A1B0Z3L4   Multi-pass membrane protein
# 48756      B3KV50                  Data unknown
# 48757      B7Z535                  Data unknown
# 48758      V5NRG0                  Data unknown
# 48759  A0A097IWB1   Multi-pass membrane protein
# 48760      J3QRY7                  Data unknown
# 48761      Q8NH99   Multi-pass membrane protein
# 48762  A0A173ADR7                  Data unknown
# 48763  A0A0D4BJE1                  Data unknown
# 48764      I6YAY1                  Data unknown
# 48765      H0YAA5                  Data unknown
# 48766      Q50KF4   Multi-pass membrane protein
# 48767      Q6H2G4                  Data unknown
# 48768      F6IQE5                  Data unknown
# 48769      L8E9C5                  Data unknown
# 48770  A0A0S4T4S3                  Data unknown
# 48771      Q2NNQ7                  Data unknown
# 48772      Q9TPW6                  Data unknown
# 48773      H7C222                  Data unknown
# 48774      P79534                  Data unknown
# 48775  A0A0D4WNW9   Multi-pass membrane protein
# 48776  A0A140VJC8                  Data unknown
# 48777      J3KSS8                  Data unknown
# 48778  A0A0G2JPM8                  Data unknown
# 48779  A0A0A6YYA3                  Data unknown
# 48780      Q7Z4X2                  Data unknown
# 48781  A0A1S5UZH4                  Data unknown
# 48782      Q8NHB6                  Data unknown
# 48783      A8K212                  Data unknown
#
#                                              Annotations
# 0                                                   None
# 1                                                   None
# 2                                            ECO:0000250
# 3                            ECO:0000269|PubMed:11309290
# 4                                            ECO:0000305
# 5                                            ECO:0000250
# 6                                            ECO:0000250
# 7                                            ECO:0000305
# 8                                            ECO:0000305
# 9                                            ECO:0000305
# 10                                           ECO:0000305
# 11                                                  None
# 12                                                  None
# 13     ECO:0000269|PubMed:19383836, ECO:0000269|PubMe...
# 14                                                  None
# 15                                           ECO:0000250
# 16                                           ECO:0000250
# 17                                                  None
# 18                                                  None
# 19                                                  None
# 20                                           ECO:0000250
# 21                                           ECO:0000250
# 22                                                  None
# 23                                           ECO:0000250
# 24                                           ECO:0000250
# 25                                           ECO:0000250
# 26                                           ECO:0000250
# 27                          ECO:0000250|UniProtKB:P37023
# 28                                                  None
# 29                                           ECO:0000305
# ...                                                  ...
# 48754                                               None
# 48755  ECO:0000256|RuleBase:RU003404, ECO:0000256|SAA...
# 48756                                               None
# 48757                                               None
# 48758                                               None
# 48759                      ECO:0000256|SAAS:SAAS00674178
# 48760                                               None
# 48761                      ECO:0000256|SAAS:SAAS00521146
# 48762                                               None
# 48763                                               None
# 48764                                               None
# 48765                                               None
# 48766                      ECO:0000256|RuleBase:RU004424
# 48767                                               None
# 48768                                               None
# 48769                                               None
# 48770                                               None
# 48771                                               None
# 48772                                               None
# 48773                                               None
# 48774                                               None
# 48775  ECO:0000256|RuleBase:RU003404, ECO:0000256|SAA...
# 48776                                               None
# 48777                                               None
# 48778                                               None
# 48779                                               None
# 48780                                               None
# 48781                                               None
# 48782                                               None
# 48783                                               None
#
# [48784 rows x 3 columns]
