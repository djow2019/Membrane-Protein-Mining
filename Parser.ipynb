# %%
# %load parser.py
# import the panda, request, io, and mygene libraries
import pandas as pd
import requests
import io
import mygene

# construct the query data
query = {

  "query": "annotation:(type:transmem) (organism:\"Homo sapiens (Human) [9606]\" OR organism:\"Mus musculus (Mouse) [10090]\")",
  "columns":"id,comment(SUBCELLULAR LOCATION)",
  "format": "tab"

}

# get the data from uni prot
r = requests.get("http://www.uniprot.org/uniprot/", params = query)

# %%
# Simple expression to find annotation data
def findAnnotation(text):
  text = str(text)
  # Now check for an annotation dictionary
  if text.find("{") != -1:
    return text[text.find("{") + 1: text.find("}")]
  else:
    return "None"

# expression to check for the type of protein
def findType(entry):
  entry = str(entry)
  # Check for single, multi, beta or other
  if entry.find("Single-pass") != -1:
    return "Single-pass membrane protein"
  elif entry.find("Multi-pass") != -1:
    return "Multi-pass membrane protein"
  elif entry.find("Beta-barrel") != -1:
    return "Beta-barrel membrane protein"
  else:
    return "Data unknown"

# read in the table data and set column names
data = pd.read_table(io.StringIO(r.text), header=0, names = ["UniProtID", "Reference"])

# Add the type column
data["Type"] = data["Reference"].apply(lambda x: findType(x))

# Add the annotation column
data["Annotations"] = data["Reference"].apply(lambda x: findAnnotation(x))

# %%
# now use mygene to add additional IDs
mg = mygene.MyGeneInfo()
out = mg.querymany(data["UniProtID"], scopes='uniprot', fields='entrezgene,ensembl.gene,refseq,symbol,taxid', returnall=True)
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-8000...done.
# querying 8001-9000...done.
# querying 9001-10000...done.
# querying 10001-11000...done.
# querying 11001-12000...done.
# querying 12001-13000...done.
# querying 13001-14000...done.
# querying 14001-15000...done.
# querying 15001-16000...done.
# querying 16001-17000...done.
# querying 17001-18000...done.
# querying 18001-19000...done.
# querying 19001-20000...done.
# querying 20001-21000...done.
# querying 21001-22000...done.
# querying 22001-23000...done.
# querying 23001-24000...done.
# querying 24001-25000...done.
# querying 25001-26000...done.
# querying 26001-27000...done.
# querying 27001-28000...done.
# querying 28001-29000...done.
# querying 29001-30000...done.
# querying 30001-31000...done.
# querying 31001-32000...done.
# querying 32001-33000...done.
# querying 33001-34000...done.
# querying 34001-35000...done.
# querying 35001-36000...done.
# querying 36001-37000...done.
# querying 37001-38000...done.
# querying 38001-39000...done.
# querying 39001-40000...done.
# querying 40001-41000...done.
# querying 41001-42000...done.
# querying 42001-43000...done.
# querying 43001-44000...done.
# querying 44001-45000...done.
# querying 45001-46000...done.
# querying 46001-47000...done.
# querying 47001-48000...done.
# querying 48001-48946...done.
# Finished.
# 171 input query terms found dup hits:
# 	[('Q9Y3B3', 2), ('A5PLL7', 2), ('Q9CQV7', 2), ('Q9R0Q3', 2), ('O43508', 2), ('Q96ET8', 2), ('Q9Y4X1'
# 24056 input query terms found no hit:
# 	['P59539', 'Q91XD3', 'Q9WTS5', 'P86176', 'Q9WTQ8', 'Q6UXP3', 'Q60774', 'A8MYB1', 'P69525', 'Q9Z0W1',

# %%
def getTax(value):
    # Value might be not found, so treat as string
    value = str(value)
    if value == "9606":
        return "Human"
    elif value == "10090":
        return "Mouse"
    else:
        return "Unknown"
    
# change all values to mouse/human
for entry in out["out"]:
    if "taxid" in entry:
        entry["taxid"] = getTax(entry["taxid"])

# %%
#create a separate dictionary for duplicates
duplicates = {}
for k, v in out["dup"]:
    duplicates[k] = v
    
# create a list of all the duplicates
dups = [entry for entry in out["out"] if entry["query"] in duplicates]

# whether or not an entry is unique
def isUnique(entry):
    
    # check if query is a duplicate
    if entry["query"] in duplicates:
        
        #check if the duplicate has been merged
        if duplicates[entry["query"]] > 1:
            
            # get a list of the current duplicates
            entries = [dup for dup in dups if dup["query"] == entry["query"]]
            
            # now merge each category
            entry["entrezgene"] = [item["entrezgene"] for item in entries if "entrezgene" in item]
            entry["ensembl"] = [item["ensembl"] for item in entries if "ensembl" in item]
            entry["refseq"] = [item["refseq"] for item in entries if "refseq" in item]
            entry["symbol"] = [item["symbol"] for item in entries if "symbol" in item]
            entry["taxid"] = [item["taxid"] for item in entries if "taxid" in item]
            
            # mark as merged
            duplicates[entry["query"]] = 1
            return True
        else:
            return False
    else:
        return True

#filter out duplicates
parsed = [entry for entry in  out["out"] if isUnique(entry)]

# %%
data["EntrezID"] = pd.Series(map(lambda d: d.get('entrezgene', 'Not Found'), parsed))
data["EnsemblID"] = pd.Series(map(lambda d: d.get('ensembl', 'Not Found'), parsed))
data["RefSeqID"] = pd.Series(map(lambda d: d.get('refseq', 'Not Found'), parsed))
data["Symbol"] = pd.Series(map(lambda d: d.get('symbol', 'Not Found'), parsed))
data["TaxID"] = pd.Series(map(lambda d: d.get('taxid', 'Not Found'), parsed))

# %%
# now write the table to a file
data.to_csv("formatted.tab", index=False, header=True, sep="	")

# %%
data
# Out:
#         UniProtID                                          Reference  \
# 0          Q9NYW0  SUBCELLULAR LOCATION: Membrane; Multi-pass mem...
# 1          Q9NYV9  SUBCELLULAR LOCATION: Membrane; Multi-pass mem...
# 2          P59538  SUBCELLULAR LOCATION: Membrane; Multi-pass mem...
# 3          Q7TQA6  SUBCELLULAR LOCATION: Membrane; Multi-pass mem...
# 4          Q7TQA5  SUBCELLULAR LOCATION: Membrane; Multi-pass mem...
# 5          Q7TQB8  SUBCELLULAR LOCATION: Membrane; Multi-pass mem...
# 6          P59539  SUBCELLULAR LOCATION: Membrane; Multi-pass mem...
# 7          Q8C0G2  SUBCELLULAR LOCATION: Membrane {ECO:0000305}; ...
# 8          Q96CE8  SUBCELLULAR LOCATION: Membrane {ECO:0000305}; ...
# 9          Q91XD3  SUBCELLULAR LOCATION: Membrane {ECO:0000250}; ...
# 10         Q8BGV3  SUBCELLULAR LOCATION: Membrane {ECO:0000250}; ...
# 11         Q9D9I4  SUBCELLULAR LOCATION: Membrane {ECO:0000305}; ...
# 12         Q5SVR0  SUBCELLULAR LOCATION: Membrane {ECO:0000305}; ...
# 13         Q8WWU5  SUBCELLULAR LOCATION: Membrane {ECO:0000305}; ...
# 14         Q6PFE7  SUBCELLULAR LOCATION: Cell membrane {ECO:00002...
# 15         Q9QYM9  SUBCELLULAR LOCATION: Membrane {ECO:0000305}; ...
# 16     A0A1B0GUA7  SUBCELLULAR LOCATION: Membrane {ECO:0000255}; ...
# 17         Q9UPZ6  SUBCELLULAR LOCATION: Cell membrane {ECO:00002...
# 18         Q9C0I4  SUBCELLULAR LOCATION: Membrane {ECO:0000305}; ...
# 19         Q9NS62  SUBCELLULAR LOCATION: Isoform 1: Membrane {ECO...
# 20         Q9UIK5  SUBCELLULAR LOCATION: Isoform 1: Membrane {ECO...
# 21         Q9UKZ4  SUBCELLULAR LOCATION: Cell membrane {ECO:00002...
# 22         Q9NT68  SUBCELLULAR LOCATION: Cell membrane {ECO:00002...
# 23         Q9WTS5  SUBCELLULAR LOCATION: Cell membrane {ECO:00002...
# 24         Q9P273  SUBCELLULAR LOCATION: Membrane {ECO:0000305}; ...
# 25         Q62351  SUBCELLULAR LOCATION: Cell membrane {ECO:00002...
# 26         O88393  SUBCELLULAR LOCATION: Cell membrane {ECO:00002...
# 27         Q8BI84  SUBCELLULAR LOCATION: Endoplasmic reticulum me...
# 28         Q9Z0V7  SUBCELLULAR LOCATION: Mitochondrion inner memb...
# 29         Q9NPL8  SUBCELLULAR LOCATION: Mitochondrion membrane {...
# ...           ...                                                ...
# 48916  A0A140T8X9                                                NaN
# 48917      H9NPM6  SUBCELLULAR LOCATION: Mitochondrion inner memb...
# 48918      Q7Z3R2                                                NaN
# 48919      I3Q468  SUBCELLULAR LOCATION: Mitochondrion inner memb...
# 48920      Q9HAM9                                                NaN
# 48921      T1Q5E5  SUBCELLULAR LOCATION: Mitochondrion membrane {...
# 48922  A0A1B5BA03                                                NaN
# 48923  A0A1D9ITY9                                                NaN
# 48924      Q6Q320                                                NaN
# 48925      L7NV95                                                NaN
# 48926  A0A1D8RFH8  SUBCELLULAR LOCATION: Mitochondrion inner memb...
# 48927  A0A1S7C6F1  SUBCELLULAR LOCATION: Mitochondrion inner memb...
# 48928  A0A059RSK8  SUBCELLULAR LOCATION: Mitochondrion inner memb...
# 48929  A0A1W2PRX6                                                NaN
# 48930  A0A1W2PRB0                                                NaN
# 48931      Q308M1                                                NaN
# 48932      A0PJF5                                                NaN
# 48933      V9JBQ6                                                NaN
# 48934      Q9UMI4                                                NaN
# 48935  A0A059RN67  SUBCELLULAR LOCATION: Mitochondrion inner memb...
# 48936  A0A141ZRB0  SUBCELLULAR LOCATION: Mitochondrion inner memb...
# 48937  A0A126GW20  SUBCELLULAR LOCATION: Cell membrane {ECO:00002...
# 48938  A0A1W2PQD1                                                NaN
# 48939      B4E2S7  SUBCELLULAR LOCATION: Lysosome membrane {ECO:0...
# 48940  A0A0S2Z4F4                                                NaN
# 48941  A0A126GWN3  SUBCELLULAR LOCATION: Cell membrane {ECO:00002...
# 48942      D9MZ72  SUBCELLULAR LOCATION: Mitochondrion inner memb...
# 48943      B4E1D4                                                NaN
# 48944  A0A0S2Z4S0                                                NaN
# 48945      B5BNW9                                                NaN
#
#                                Type  \
# 0       Multi-pass membrane protein
# 1       Multi-pass membrane protein
# 2       Multi-pass membrane protein
# 3       Multi-pass membrane protein
# 4       Multi-pass membrane protein
# 5       Multi-pass membrane protein
# 6       Multi-pass membrane protein
# 7      Single-pass membrane protein
# 8       Multi-pass membrane protein
# 9       Multi-pass membrane protein
# 10     Single-pass membrane protein
# 11      Multi-pass membrane protein
# 12     Single-pass membrane protein
# 13     Single-pass membrane protein
# 14     Single-pass membrane protein
# 15     Single-pass membrane protein
# 16     Single-pass membrane protein
# 17     Single-pass membrane protein
# 18     Single-pass membrane protein
# 19     Single-pass membrane protein
# 20     Single-pass membrane protein
# 21     Single-pass membrane protein
# 22     Single-pass membrane protein
# 23     Single-pass membrane protein
# 24     Single-pass membrane protein
# 25     Single-pass membrane protein
# 26     Single-pass membrane protein
# 27     Single-pass membrane protein
# 28      Multi-pass membrane protein
# 29      Multi-pass membrane protein
# ...                             ...
# 48916                  Data unknown
# 48917                  Data unknown
# 48918                  Data unknown
# 48919   Multi-pass membrane protein
# 48920                  Data unknown
# 48921   Multi-pass membrane protein
# 48922                  Data unknown
# 48923                  Data unknown
# 48924                  Data unknown
# 48925                  Data unknown
# 48926   Multi-pass membrane protein
# 48927   Multi-pass membrane protein
# 48928   Multi-pass membrane protein
# 48929                  Data unknown
# 48930                  Data unknown
# 48931                  Data unknown
# 48932                  Data unknown
# 48933                  Data unknown
# 48934                  Data unknown
# 48935   Multi-pass membrane protein
# 48936   Multi-pass membrane protein
# 48937   Multi-pass membrane protein
# 48938                  Data unknown
# 48939  Single-pass membrane protein
# 48940                  Data unknown
# 48941   Multi-pass membrane protein
# 48942   Multi-pass membrane protein
# 48943                  Data unknown
# 48944                  Data unknown
# 48945                  Data unknown
#
#                                              Annotations   EntrezID  \
# 0                                                   None      50839
# 1                                                   None      50838
# 2                                                   None     259290
# 3                                                   None     387513
# 4                                                   None     353148
# 5                                                   None     387515
# 6                                                   None  Not Found
# 7                                            ECO:0000305     215243
# 8                                            ECO:0000305     116441
# 9                                            ECO:0000250  Not Found
# 10                                           ECO:0000250      56753
# 11                                           ECO:0000305      67231
# 12                                           ECO:0000305      76795
# 13                                           ECO:0000305       6954
# 14                                           ECO:0000250     230157
# 15                                           ECO:0000305      56363
# 16                                           ECO:0000255  101929926
# 17                           ECO:0000269|PubMed:22194972     221981
# 18                                           ECO:0000305      80731
# 19                                           ECO:0000305      55901
# 20                                           ECO:0000305      23671
# 21                                           ECO:0000250      10178
# 22                                           ECO:0000250      57451
# 23                                           ECO:0000250  Not Found
# 24                                           ECO:0000305      55714
# 25                          ECO:0000250|UniProtKB:P02786      22042
# 26                                           ECO:0000250      21814
# 27                          ECO:0000250|UniProtKB:Q5JRA6     338366
# 28                                                  None      21855
# 29                           ECO:0000269|PubMed:24191001      51300
# ...                                                  ...        ...
# 48916                                               None      10665
# 48917                      ECO:0000256|RuleBase:RU362117  Not Found
# 48918                                               None  Not Found
# 48919                      ECO:0000256|RuleBase:RU004450  Not Found
# 48920                                               None  Not Found
# 48921                      ECO:0000256|SAAS:SAAS00410259  Not Found
# 48922                                               None  Not Found
# 48923                                               None  Not Found
# 48924                                               None  Not Found
# 48925                                               None  Not Found
# 48926                      ECO:0000256|RuleBase:RU004450  Not Found
# 48927                      ECO:0000256|RuleBase:RU004450  Not Found
# 48928                      ECO:0000256|RuleBase:RU000471  Not Found
# 48929                                               None       3778
# 48930                                               None       3778
# 48931                                               None  Not Found
# 48932                                               None       5734
# 48933                                               None  Not Found
# 48934                                               None  Not Found
# 48935                      ECO:0000256|RuleBase:RU000471  Not Found
# 48936  ECO:0000256|RuleBase:RU003404, ECO:0000256|SAA...  Not Found
# 48937                      ECO:0000256|SAAS:SAAS00857205     390181
# 48938                                               None       1798
# 48939               ECO:0000256|PROSITE-ProRule:PRU00740  Not Found
# 48940                                               None       6901
# 48941                      ECO:0000256|SAAS:SAAS00857205     119692
# 48942                      ECO:0000256|RuleBase:RU000369  Not Found
# 48943                                               None  Not Found
# 48944                                               None  Not Found
# 48945                                               None  Not Found
#
#                                                EnsemblID  \
# 0      [{'gene': 'ENSG00000272805'}, {'gene': 'ENSG00...
# 1      [{'gene': 'ENSG00000273457'}, {'gene': 'ENSG00...
# 2      [{'gene': 'ENSG00000256436'}, {'gene': 'ENSG00...
# 3                         {'gene': 'ENSMUSG00000058250'}
# 4                         {'gene': 'ENSMUSG00000047102'}
# 5                         {'gene': 'ENSMUSG00000051917'}
# 6                                              Not Found
# 7                         {'gene': 'ENSMUSG00000037318'}
# 8                            {'gene': 'ENSG00000163762'}
# 9                                              Not Found
# 10                        {'gene': 'ENSMUSG00000051397'}
# 11                        {'gene': 'ENSMUSG00000027465'}
# 12                        {'gene': 'ENSMUSG00000036644'}
# 13                           {'gene': 'ENSG00000124678'}
# 14                        {'gene': 'ENSMUSG00000028347'}
# 15                        {'gene': 'ENSMUSG00000026109'}
# 16                           {'gene': 'ENSG00000237524'}
# 17                           {'gene': 'ENSG00000005108'}
# 18                           {'gene': 'ENSG00000144229'}
# 19                           {'gene': 'ENSG00000136114'}
# 20                           {'gene': 'ENSG00000144339'}
# 21                           {'gene': 'ENSG00000009694'}
# 22                           {'gene': 'ENSG00000145934'}
# 23                                             Not Found
# 24                           {'gene': 'ENSG00000218336'}
# 25                        {'gene': 'ENSMUSG00000022797'}
# 26                        {'gene': 'ENSMUSG00000029287'}
# 27                                             Not Found
# 28                        {'gene': 'ENSMUSG00000031158'}
# 29                           {'gene': 'ENSG00000113845'}
# ...                                                  ...
# 48916  [{'gene': 'ENSG00000237881'}, {'gene': 'ENSG00...
# 48917                                          Not Found
# 48918                                          Not Found
# 48919                                          Not Found
# 48920                                          Not Found
# 48921                                          Not Found
# 48922                                          Not Found
# 48923                                          Not Found
# 48924                                          Not Found
# 48925                                          Not Found
# 48926                                          Not Found
# 48927                                          Not Found
# 48928                                          Not Found
# 48929                        {'gene': 'ENSG00000156113'}
# 48930                        {'gene': 'ENSG00000156113'}
# 48931                                          Not Found
# 48932                        {'gene': 'ENSG00000171522'}
# 48933                                          Not Found
# 48934                                          Not Found
# 48935                                          Not Found
# 48936                                          Not Found
# 48937                        {'gene': 'ENSG00000181273'}
# 48938                        {'gene': 'ENSG00000172269'}
# 48939                                          Not Found
# 48940                        {'gene': 'ENSG00000102125'}
# 48941                        {'gene': 'ENSG00000176922'}
# 48942                                          Not Found
# 48943                                          Not Found
# 48944                                          Not Found
# 48945                                          Not Found
#
#                                                 RefSeqID     Symbol      TaxID
# 0      {'genomic': ['NC_000012.12', 'NC_018923.2', 'N...    TAS2R10      Human
# 1      {'genomic': ['NC_000012.12', 'NC_018923.2', 'N...    TAS2R13      Human
# 2      {'genomic': ['NC_000012.12', 'NC_018923.2', 'N...    TAS2R31      Human
# 3      {'genomic': 'NC_000072.6', 'protein': 'NP_0010...   Tas2r138      Mouse
# 4      {'genomic': 'NC_000072.6', 'protein': 'NP_8517...   Tas2r139      Mouse
# 5      {'genomic': 'NC_000072.6', 'protein': 'NP_0010...   Tas2r144      Mouse
# 6                                              Not Found  Not Found  Not Found
# 7      {'genomic': 'NC_000067.6', 'protein': 'NP_6947...   Traf3ip3      Mouse
# 8      {'genomic': ['NC_000003.12', 'NC_018914.2'], '...    TM4SF18      Human
# 9                                              Not Found  Not Found  Not Found
# 10     {'genomic': 'NC_000072.6', 'protein': 'NP_0644...    Tacstd2      Mouse
# 11     {'genomic': 'NC_000068.7', 'protein': 'NP_0771...    Tbc1d20      Mouse
# 12     {'genomic': 'NC_000077.6', 'protein': ['NP_001...    Tbc1d9b      Mouse
# 13     {'genomic': ['NC_000006.12', 'NC_018917.2'], '...      TCP11      Human
# 14     {'genomic': 'NC_000070.6', 'protein': ['NP_001...     Tmeff1      Mouse
# 15     {'genomic': 'NC_000067.6', 'protein': 'NP_0627...     Tmeff2      Mouse
# 16     {'genomic': ['NC_000002.12', 'NC_018913.2'], '...      TEX51      Human
# 17     {'genomic': ['NC_000007.14', 'NC_018918.2', 'N...     THSD7A      Human
# 18     {'genomic': ['NC_000002.12', 'NC_018913.2'], '...     THSD7B      Human
# 19     {'genomic': ['NC_000013.11', 'NC_018924.2', 'N...      THSD1      Human
# 20     {'genomic': ['NC_000002.12', 'NC_018913.2'], '...     TMEFF2      Human
# 21     {'genomic': ['NC_000023.11', 'NC_018934.2', 'N...      TENM1      Human
# 22     {'genomic': ['NC_000005.10', 'NC_018916.2'], '...      TENM2      Human
# 23                                             Not Found  Not Found  Not Found
# 24     {'genomic': ['NC_000004.12', 'NC_018915.2', 'N...      TENM3      Human
# 25     {'genomic': 'NC_000082.6', 'protein': ['NP_035...       Tfrc      Mouse
# 26     {'genomic': 'NC_000071.6', 'protein': 'NP_0357...     Tgfbr3      Mouse
# 27     {'genomic': 'NC_000067.6', 'protein': 'NP_7963...       Mia3      Mouse
# 28     {'genomic': 'NC_000086.7', 'protein': ['NP_001...    Timm17b      Mouse
# 29     {'genomic': ['NC_000003.12', 'NC_018914.2'], '...    TIMMDC1      Human
# ...                                                  ...        ...        ...
# 48916  {'genomic': ['NC_000006.12', 'NC_018917.2', 'N...    C6orf10      Human
# 48917                                          Not Found  Not Found  Not Found
# 48918                                          Not Found  Not Found  Not Found
# 48919                                          Not Found  Not Found  Not Found
# 48920                                          Not Found  Not Found  Not Found
# 48921                                          Not Found  Not Found  Not Found
# 48922                                          Not Found  Not Found  Not Found
# 48923                                          Not Found  Not Found  Not Found
# 48924                                          Not Found  Not Found  Not Found
# 48925                                          Not Found  Not Found  Not Found
# 48926                                          Not Found  Not Found  Not Found
# 48927                                          Not Found  Not Found  Not Found
# 48928                                          Not Found  Not Found  Not Found
# 48929  {'genomic': ['NC_000010.11', 'NC_018921.2', 'N...     KCNMA1      Human
# 48930  {'genomic': ['NC_000010.11', 'NC_018921.2', 'N...     KCNMA1      Human
# 48931                                          Not Found  Not Found  Not Found
# 48932  {'genomic': ['NC_000005.10', 'NC_018916.2', 'N...     PTGER4      Human
# 48933                                          Not Found  Not Found  Not Found
# 48934                                          Not Found  Not Found  Not Found
# 48935                                          Not Found  Not Found  Not Found
# 48936                                          Not Found  Not Found  Not Found
# 48937  {'genomic': ['NC_000011.10', 'NC_018922.2'], '...     OR5AK2      Human
# 48938  {'genomic': ['NC_000011.10', 'NC_018922.2', 'N...     DPAGT1      Human
# 48939                                          Not Found  Not Found  Not Found
# 48940  {'genomic': ['NC_000023.11', 'NC_018934.2', 'N...        TAZ      Human
# 48941  {'genomic': ['NC_000011.10', 'NC_018922.2'], '...     OR51S1      Human
# 48942                                          Not Found  Not Found  Not Found
# 48943                                          Not Found  Not Found  Not Found
# 48944                                          Not Found  Not Found  Not Found
# 48945                                          Not Found  Not Found  Not Found
#
# [48946 rows x 9 columns]
